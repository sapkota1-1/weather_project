# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\saikrishna.kasa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.24.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\saikrishna.kasa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.2.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\saikrishna.kasa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\saikrishna.kasa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\saikrishna.kasa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %matplotlib inline

# %%
weather_df = pd.read_csv('hyderabad.csv', parse_dates=['date_time'], index_col='date_time')
weather_df.head(10)
# Out:
#                      maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# date_time
# 2009-01-01 00:00:00        28        15             0      8.7        6
# 2009-01-01 01:00:00        28        15             0      8.7        6
# 2009-01-01 02:00:00        28        15             0      8.7        6
# 2009-01-01 03:00:00        28        15             0      8.7        6
# 2009-01-01 04:00:00        28        15             0      8.7        6
# 2009-01-01 05:00:00        28        15             0      8.7        6
# 2009-01-01 06:00:00        28        15             0      8.7        6
# 2009-01-01 07:00:00        28        15             0      8.7        6
# 2009-01-01 08:00:00        28        15             0      8.7        6
# 2009-01-01 09:00:00        28        15             0      8.7        6
#
#                      uvIndex.1  moon_illumination moonrise  moonset  sunrise  \
# date_time
# 2009-01-01 00:00:00          1                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 01:00:00          1                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 02:00:00          1                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 03:00:00          1                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 04:00:00          1                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 05:00:00          1                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 06:00:00          6                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 07:00:00          6                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 08:00:00          6                 31  9:57 AM  9:58 PM  6:46 AM
# 2009-01-01 09:00:00          7                 31  9:57 AM  9:58 PM  6:46 AM
#
#                      ... WindChillC  WindGustKmph  cloudcover  humidity  \
# date_time            ...
# 2009-01-01 00:00:00  ...         21             9           0        83
# 2009-01-01 01:00:00  ...         20             9           0        85
# 2009-01-01 02:00:00  ...         20             8           0        86
# 2009-01-01 03:00:00  ...         19             8           0        88
# 2009-01-01 04:00:00  ...         21             7           0        80
# 2009-01-01 05:00:00  ...         23             6           0        72
# 2009-01-01 06:00:00  ...         25             5           0        64
# 2009-01-01 07:00:00  ...         26             6           0        54
# 2009-01-01 08:00:00  ...         28             7           0        45
# 2009-01-01 09:00:00  ...         30             8           0        35
#
#                      precipMM  pressure  tempC  visibility  winddirDegree  \
# date_time
# 2009-01-01 00:00:00       0.0      1013     16          10            150
# 2009-01-01 01:00:00       0.0      1013     16          10            148
# 2009-01-01 02:00:00       0.0      1013     15          10            147
# 2009-01-01 03:00:00       0.0      1013     15          10            145
# 2009-01-01 04:00:00       0.0      1014     16          10            148
# 2009-01-01 05:00:00       0.0      1015     18          10            151
# 2009-01-01 06:00:00       0.0      1015     20          10            153
# 2009-01-01 07:00:00       0.0      1015     22          10            139
# 2009-01-01 08:00:00       0.0      1014     24          10            125
# 2009-01-01 09:00:00       0.0      1014     26          10            110
#
#                      windspeedKmph
# date_time
# 2009-01-01 00:00:00              6
# 2009-01-01 01:00:00              5
# 2009-01-01 02:00:00              5
# 2009-01-01 03:00:00              5
# 2009-01-01 04:00:00              5
# 2009-01-01 05:00:00              4
# 2009-01-01 06:00:00              4
# 2009-01-01 07:00:00              5
# 2009-01-01 08:00:00              6
# 2009-01-01 09:00:00              7
#
# [10 rows x 24 columns]

# %%
weather_df.columns
# Out:
# Index(['maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'uvIndex.1', 'moon_illumination', 'moonrise', 'moonset', 'sunrise',
#        'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC',
#        'WindGustKmph', 'cloudcover', 'humidity', 'precipMM', 'pressure',
#        'tempC', 'visibility', 'winddirDegree', 'windspeedKmph'],
#       dtype='object')

# %%
weather_df.isnull().any()
# Out:
# maxtempC             False
# mintempC             False
# totalSnow_cm         False
# sunHour              False
# uvIndex              False
# uvIndex.1            False
# moon_illumination    False
# moonrise             False
# moonset              False
# sunrise              False
# sunset               False
# DewPointC            False
# FeelsLikeC           False
# HeatIndexC           False
# WindChillC           False
# WindGustKmph         False
# cloudcover           False
# humidity             False
# precipMM             False
# pressure             False
# tempC                False
# visibility           False
# winddirDegree        False
# windspeedKmph        False
# dtype: bool

# %%
weather_df_num=weather_df.loc[:,['maxtempC','mintempC','cloudcover','humidity','tempC', 'sunHour','HeatIndexC', 'precipMM', 'pressure','windspeedKmph']]
weather_df_num.head()
# Out:
#                      maxtempC  mintempC  cloudcover  humidity  tempC  sunHour  \
# date_time
# 2009-01-01 00:00:00        28        15           0        83     16      8.7
# 2009-01-01 01:00:00        28        15           0        85     16      8.7
# 2009-01-01 02:00:00        28        15           0        86     15      8.7
# 2009-01-01 03:00:00        28        15           0        88     15      8.7
# 2009-01-01 04:00:00        28        15           0        80     16      8.7
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2009-01-01 00:00:00          21       0.0      1013              6
# 2009-01-01 01:00:00          20       0.0      1013              5
# 2009-01-01 02:00:00          20       0.0      1013              5
# 2009-01-01 03:00:00          19       0.0      1013              5
# 2009-01-01 04:00:00          22       0.0      1014              5

# %%
weather_df_num.shape
# Out:
# (96432, 10)

# %%
weather_df_num.columns
# Out:
# Index(['maxtempC', 'mintempC', 'cloudcover', 'humidity', 'tempC', 'sunHour',
#        'HeatIndexC', 'precipMM', 'pressure', 'windspeedKmph'],
#       dtype='object')

# %%
weather_df_num.columns
# Out:
# Index(['maxtempC', 'mintempC', 'cloudcover', 'humidity', 'tempC', 'sunHour',
#        'HeatIndexC', 'precipMM', 'pressure', 'windspeedKmph'],
#       dtype='object')

# %%
weather_df_num.plot(subplots=True, figsize=(25,20))
# Out:
# array([<AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>], dtype=object)

# %%
weather_df_num['2019':'2020'].resample('D').fillna(method='pad').plot(subplots=True, figsize=(25,20))
# Out:
# array([<AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>,
#        <AxesSubplot: xlabel='date_time'>], dtype=object)

# %%
weather_df_num.hist(bins=10,figsize=(15,15))
# Out:
# array([[<AxesSubplot: title={'center': 'maxtempC'}>,
#         <AxesSubplot: title={'center': 'mintempC'}>,
#         <AxesSubplot: title={'center': 'cloudcover'}>],
#        [<AxesSubplot: title={'center': 'humidity'}>,
#         <AxesSubplot: title={'center': 'tempC'}>,
#         <AxesSubplot: title={'center': 'sunHour'}>],
#        [<AxesSubplot: title={'center': 'HeatIndexC'}>,
#         <AxesSubplot: title={'center': 'precipMM'}>,
#         <AxesSubplot: title={'center': 'pressure'}>],
#        [<AxesSubplot: title={'center': 'windspeedKmph'}>,
#         <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
weth=weather_df_num['2019':'2020']
weth.head()
# Out:
#                      maxtempC  mintempC  cloudcover  humidity  sunHour  \
# date_time
# 2019-01-01 00:00:00        29        19           0        26      8.7
# 2019-01-01 01:00:00        29        19           0        26      8.7
# 2019-01-01 02:00:00        29        19           0        27      8.7
# 2019-01-01 03:00:00        29        19           0        27      8.7
# 2019-01-01 04:00:00        29        19           0        26      8.7
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2019-01-01 00:00:00          22       0.0      1019              7
# 2019-01-01 01:00:00          21       0.0      1019              7
# 2019-01-01 02:00:00          21       0.0      1019              7
# 2019-01-01 03:00:00          20       0.0      1019              7
# 2019-01-01 04:00:00          20       0.0      1019              7

# %%
weather_y=weather_df_num.pop("tempC")
weather_x=weather_df_num

# %%
train_X,test_X,train_y,test_y=train_test_split(weather_x,weather_y,test_size=0.2,random_state=4)

# %%
train_X.shape
# Out:
# (77145, 9)

# %%
train_y.shape
# Out:
# (77145,)

# %%
train_y.head()
# Out:
# date_time
# 2012-03-13 07:00:00    27
# 2009-11-05 21:00:00    21
# 2017-10-11 22:00:00    27
# 2019-06-08 11:00:00    35
# 2019-03-06 05:00:00    28
# Name: tempC, dtype: int64

# %%
plt.scatter(weth.mintempC, weth.tempC)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.HeatIndexC, weth.tempC)
plt.xlabel("Heat Index")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.pressure, weth.tempC)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()

# %%
plt.scatter(weth.mintempC, weth.tempC)
plt.xlabel("Minimum Temperature")
plt.ylabel("Temperature")
plt.show()

# %%
model=LinearRegression()
model.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
prediction = model.predict(test_X)

# %%
#calculating error
np.mean(np.absolute(prediction-test_y))
# Out:
# 0.8469137745291704

# %%
print('Variance score: %.2f' % model.score(test_X, test_y))
# Out:
# Variance score: 0.95

# %%
for i in range(len(prediction)):
  prediction[i]=round(prediction[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction,'diff':(test_y-prediction)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2013-07-10 08:00:00      25       25.01 -0.01
# 2015-11-04 20:00:00      23       23.17 -0.17
# 2015-09-21 09:00:00      29       28.93  0.07
# 2017-02-16 11:00:00      30       28.12  1.88
# 2012-07-21 01:00:00      23       22.82  0.18
# ...                     ...         ...   ...
# 2019-03-30 09:00:00      33       32.93  0.07
# 2015-11-12 12:00:00      30       29.09  0.91
# 2019-12-31 05:00:00      18       16.95  1.05
# 2019-08-02 17:00:00      23       22.84  0.16
# 2019-10-22 08:00:00      24       22.39  1.61
#
# [19287 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
prediction2=regressor.predict(test_X)
np.mean(np.absolute(prediction2-test_y))
# Out:
# 0.4342303105718878

# %%
print('Variance score: %.2f' % regressor.score(test_X, test_y))
# Out:
# Variance score: 0.97

# %%
for i in range(len(prediction2)):
  prediction2[i]=round(prediction2[i],2)
pd.DataFrame({'Actual':test_y,'Prediction':prediction2,'diff':(test_y-prediction2)})
# Out:
#                      Actual  Prediction  diff
# date_time
# 2013-07-10 08:00:00      25        25.0   0.0
# 2015-11-04 20:00:00      23        23.0   0.0
# 2015-09-21 09:00:00      29        29.0   0.0
# 2017-02-16 11:00:00      30        30.0   0.0
# 2012-07-21 01:00:00      23        23.0   0.0
# ...                     ...         ...   ...
# 2019-03-30 09:00:00      33        33.0   0.0
# 2015-11-12 12:00:00      30        30.0   0.0
# 2019-12-31 05:00:00      18        18.0   0.0
# 2019-08-02 17:00:00      23        23.0   0.0
# 2019-10-22 08:00:00      24        22.0   2.0
#
# [19287 rows x 3 columns]

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# save the model to a file

# %%
with open('weather_prediction_model.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
first_row = test_X.iloc[[0]]
print(first_row.shape)
# get the datatypes of the elements in the first row
print(first_row)
dtypes = first_row.dtypes
print(dtypes)
# for i in test_X:
#     print(i)
#     print(type(i))
prediction = model.predict(first_row)
print(first_row)
# Out:
# (1, 9)
#                      maxtempC  mintempC  cloudcover  humidity  sunHour  \
# date_time
# 2013-07-10 08:00:00        27        23          76        77      8.2
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2013-07-10 08:00:00          27       0.0      1003             17
# maxtempC           int64
# mintempC           int64
# cloudcover         int64
# humidity           int64
# sunHour          float64
# HeatIndexC         int64
# precipMM         float64
# pressure           int64
# windspeedKmph      int64
# dtype: object

# %%
print(prediction)
print(first_row)
# Out:
# [25.00575037]
#                      maxtempC  mintempC  cloudcover  humidity  sunHour  \
# date_time
# 2013-07-10 08:00:00        27        23          76        77      8.2
#
#                      HeatIndexC  precipMM  pressure  windspeedKmph
# date_time
# 2013-07-10 08:00:00          27       0.0      1003             17

# %%
model.predict([[27,23,76,77,8.2,27,0.0,1003,17]])
# Out:
# array([25.00575037])

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)
